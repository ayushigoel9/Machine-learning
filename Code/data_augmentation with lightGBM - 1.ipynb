# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
import matplotlib
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold,KFold
import warnings
from six.moves import urllib
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings('ignore')
# %matplotlib inline
plt.style.use('seaborn')
from scipy.stats import norm, skew

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
features = [c for c in train.columns if c not in ['ID_code', 'target']]

# %%
def augment(x,y,t=2):
    xs,xn = [],[]
    for i in range(t):
        mask = y>0
        x1 = x[mask].copy()
        ids = np.arange(x1.shape[0])
        for c in range(x1.shape[1]):
            np.random.shuffle(ids)
            x1[:,c] = x1[ids][:,c]
        xs.append(x1)

    for i in range(t//2):
        mask = y==0
        x1 = x[mask].copy()
        ids = np.arange(x1.shape[0])
        for c in range(x1.shape[1]):
            np.random.shuffle(ids)
            x1[:,c] = x1[ids][:,c]
        xn.append(x1)

    xs = np.vstack(xs)
    xn = np.vstack(xn)
    ys = np.ones(xs.shape[0])
    yn = np.zeros(xn.shape[0])
    x = np.vstack([x,xs,xn])
    y = np.concatenate([y,ys,yn])
    return x,y

# %%
param = {
    'bagging_freq': 5,
    'bagging_fraction': 0.335,
    'boost_from_average':'false',
    'boost': 'gbdt',
    'feature_fraction': 0.041,
    'learning_rate': 0.0083,
    'max_depth': -1,
    'metric':'auc',
    'min_data_in_leaf': 80,
    'min_sum_hessian_in_leaf': 10.0,
    'num_leaves': 13,
    'num_threads': 8,
    'tree_learner': 'serial',
    'objective': 'binary', 
    'verbosity': -1
}

# %%
target = train['target']
train = train.drop(["ID_code", "target"], axis=1)

# %%
num_folds = 11
features = [c for c in train.columns if c not in ['ID_code', 'target']]

folds = KFold(n_splits=num_folds, random_state=2319)
oof = np.zeros(len(train))
getVal = np.zeros(len(train))
predictions = np.zeros(len(target))
feature_importance_df = pd.DataFrame()

print('Light GBM Model')
for fold_, (trn_idx, val_idx) in enumerate(folds.split(train.values, target.values)):
    
    X_train, y_train = train.iloc[trn_idx][features], target.iloc[trn_idx]
    X_valid, y_valid = train.iloc[val_idx][features], target.iloc[val_idx]
    
    X_tr, y_tr = augment(X_train.values, y_train.values)
    X_tr = pd.DataFrame(X_tr)
    
    print("Fold idx:{}".format(fold_ + 1))
    trn_data = lgb.Dataset(X_tr, label=y_tr)
    val_data = lgb.Dataset(X_valid, label=y_valid)
    
    clf = lgb.train(param, trn_data, 1000000, valid_sets = [trn_data, val_data], verbose_eval=5000, early_stopping_rounds = 4000)
    oof[val_idx] = clf.predict(train.iloc[val_idx][features], num_iteration=clf.best_iteration)
    getVal[val_idx]+= clf.predict(train.iloc[val_idx][features], num_iteration=clf.best_iteration) / folds.n_splits
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = features
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(test[features], num_iteration=clf.best_iteration) / folds.n_splits

print("CV score: {:<8.5f}".format(roc_auc_score(target, oof)))
# Out:
# Light GBM Model
# Fold idx:1
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.911669	valid_1's auc: 0.896349
# [10000]	training's auc: 0.921634	valid_1's auc: 0.900859
# [15000]	training's auc: 0.929234	valid_1's auc: 0.901314
# Early stopping, best iteration is:
# [15211]	training's auc: 0.929533	valid_1's auc: 0.901375
# Fold idx:2
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.91266	valid_1's auc: 0.895216
# [10000]	training's auc: 0.922343	valid_1's auc: 0.898546
# [15000]	training's auc: 0.929858	valid_1's auc: 0.899053
# [20000]	training's auc: 0.936683	valid_1's auc: 0.898972
# Early stopping, best iteration is:
# [17074]	training's auc: 0.932768	valid_1's auc: 0.89915
# Fold idx:3
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.912774	valid_1's auc: 0.889568
# [10000]	training's auc: 0.922677	valid_1's auc: 0.892804
# [15000]	training's auc: 0.930199	valid_1's auc: 0.893135
# Early stopping, best iteration is:
# [12777]	training's auc: 0.927	valid_1's auc: 0.8933
# Fold idx:4
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.91193	valid_1's auc: 0.90008
# [10000]	training's auc: 0.921834	valid_1's auc: 0.902807
# Early stopping, best iteration is:
# [10398]	training's auc: 0.92249	valid_1's auc: 0.902875
# Fold idx:5
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.912097	valid_1's auc: 0.896068
# [10000]	training's auc: 0.921968	valid_1's auc: 0.899029
# [15000]	training's auc: 0.92951	valid_1's auc: 0.899168
# [20000]	training's auc: 0.936384	valid_1's auc: 0.899222
# Early stopping, best iteration is:
# [17250]	training's auc: 0.932655	valid_1's auc: 0.899347
# Fold idx:6
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.912242	valid_1's auc: 0.898863
# [10000]	training's auc: 0.922135	valid_1's auc: 0.901659
# [15000]	training's auc: 0.929715	valid_1's auc: 0.901956
# [20000]	training's auc: 0.936542	valid_1's auc: 0.90164
# Early stopping, best iteration is:
# [16572]	training's auc: 0.931893	valid_1's auc: 0.902217
# Fold idx:7
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.91164	valid_1's auc: 0.902774
# [10000]	training's auc: 0.921492	valid_1's auc: 0.905289
# [15000]	training's auc: 0.929	valid_1's auc: 0.90516
# Early stopping, best iteration is:
# [11072]	training's auc: 0.923197	valid_1's auc: 0.905396
# Fold idx:8
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.911924	valid_1's auc: 0.896587
# [10000]	training's auc: 0.921859	valid_1's auc: 0.899651
# [15000]	training's auc: 0.929443	valid_1's auc: 0.899803
# Early stopping, best iteration is:
# [13666]	training's auc: 0.927523	valid_1's auc: 0.899842
# Fold idx:9
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.911989	valid_1's auc: 0.90028
# [10000]	training's auc: 0.921777	valid_1's auc: 0.903592
# [15000]	training's auc: 0.929375	valid_1's auc: 0.903783
# [20000]	training's auc: 0.936284	valid_1's auc: 0.903448
# Early stopping, best iteration is:
# [16879]	training's auc: 0.932015	valid_1's auc: 0.903903
# Fold idx:10
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.912091	valid_1's auc: 0.902955
# [10000]	training's auc: 0.922018	valid_1's auc: 0.906265
# [15000]	training's auc: 0.929539	valid_1's auc: 0.906503
# Early stopping, best iteration is:
# [15703]	training's auc: 0.930528	valid_1's auc: 0.906523
# Fold idx:11
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.912071	valid_1's auc: 0.897252
# [10000]	training's auc: 0.92198	valid_1's auc: 0.900509
# [15000]	training's auc: 0.929489	valid_1's auc: 0.900644
# Early stopping, best iteration is:
# [12997]	training's auc: 0.926561	valid_1's auc: 0.90078
# CV score: 0.90122

# %%
num_sub = 26
print('Saving the Submission File')
sub = pd.DataFrame({"ID_code": test.ID_code.values})
sub["target"] = predictions
sub.to_csv('submission_aug{}.csv'.format(num_sub), index=False)
getValue = pd.DataFrame(getVal)
getValue.to_csv("Validation_kfold.csv")
# Out:
# Saving the Submission File
