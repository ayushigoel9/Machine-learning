# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib as mpl
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7   ...     var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266   ...      4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338   ...      7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155   ...      2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250   ...      4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514   ...     -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# ...

# %%
#check the distribution of target value in train dataset.

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
df['target'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('target')
ax[0].set_ylabel('')
sns.countplot('target',data=df,ax=ax[1])
ax[1].set_title('target')
plt.show()

# %%
#the density plot of variables in train dataset.
# represented with different colors the distribution for values with target value 0 and 1.
def plot_feature_distribution(df1, df2, label1, label2, features):
    i = 0
    sns.set_style('whitegrid')
    plt.figure()
    fig, ax = plt.subplots(10,10,figsize=(18,22))

    for feature in features:
        i += 1
        plt.subplot(10,10,i)
#         plt.scatter(df2[feature], df2[feature], s = 80)
#         plt.hist(df1[feature], bw=0.5,label=label1)
#         plt.hist(df2[feature], bw=0.5,label=label2)
        plt.xlabel(feature, fontsize=9)
#         locs, labels = plt.xticks()
#         plt.tick_params(axis='x', which='major', labelsize=6, pad=-6)
#         plt.tick_params(axis='y', which='major', labelsize=6)
    plt.show();

# %%
def plot_feature_distribution():
    i = 0
    sns.set_style('whitegrid')
    plt.figure()
    fig, ax = plt.subplots(10,10,figsize=(18,22))
    for i in range(1,4):
#         i += 1
        plt.subplot(10,10,i)
        plt.scatter(df.iloc[:,2], df.iloc[:,i])

        plt.xlabel(str(i), fontsize=9)
    plt.show();
plot_feature_distribution()

# %%
# t0 = df.loc[df['target'] == 0]
# t1 = df.loc[df['target'] == 1]
# features = df.columns.values[2:102]
# print(features)
# df.iloc[:,3]
# plot_feature_distribution(df, features)
# plot_feature_distribution(t0, t1, '0', '1', features)
# Out:
# ['var_0' 'var_1' 'var_2' 'var_3' 'var_4' 'var_5' 'var_6' 'var_7' 'var_8'
#  'var_9' 'var_10' 'var_11' 'var_12' 'var_13' 'var_14' 'var_15' 'var_16'
#  'var_17' 'var_18' 'var_19' 'var_20' 'var_21' 'var_22' 'var_23' 'var_24'
#  'var_25' 'var_26' 'var_27' 'var_28' 'var_29' 'var_30' 'var_31' 'var_32'
#  'var_33' 'var_34' 'var_35' 'var_36' 'var_37' 'var_38' 'var_39' 'var_40'
#  'var_41' 'var_42' 'var_43' 'var_44' 'var_45' 'var_46' 'var_47' 'var_48'
#  'var_49' 'var_50' 'var_51' 'var_52' 'var_53' 'var_54' 'var_55' 'var_56'
#  'var_57' 'var_58' 'var_59' 'var_60' 'var_61' 'var_62' 'var_63' 'var_64'
#  'var_65' 'var_66' 'var_67' 'var_68' 'var_69' 'var_70' 'var_71' 'var_72'
#  'var_73' 'var_74' 'var_75' 'var_76' 'var_77' 'var_78' 'var_79' 'var_80'
#  'var_81' 'var_82' 'var_83' 'var_84' 'var_85' 'var_86' 'var_87' 'var_88'
#  'var_89' 'var_90' 'var_91' 'var_92' 'var_93' 'var_94' 'var_95' 'var_96'
#  'var_97' 'var_98' 'var_99']
# 0        -6.7863
# 1        -4.1473
# 2        -2.7457
# ...

# %%
features = df.columns.values[102:202]
plot_feature_distribution(t0, t1, '0', '1', features)

# %%
df_test = pd.read_csv("test.csv")

# %%
df_test.head()
# Out:
#   ID_code    var_0    var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  test_0  11.0656   7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493
# 1  test_1   8.5304   1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196
# 2  test_2   5.4827 -10.3581  10.1407  7.0479  10.2628  9.8052  4.8950
# 3  test_3   8.5374  -1.3222  12.0220  6.5749   8.8458  3.1744  4.9397
# 4  test_4  11.7058  -0.1327  14.1295  7.7506   9.1035 -8.5848  6.8595
#
#      var_7   var_8   ...     var_190  var_191  var_192  var_193  var_194  \
# 0  18.2675  2.1337   ...     -2.1556  11.8495  -1.4300   2.4508  13.7112
# 1  18.6316 -4.4131   ...     10.6165   8.8349   0.9403  10.1282  15.5765
# 2  20.2537  1.5233   ...     -0.7484  10.9935   1.9803   2.1800  12.9813
# 3  20.5660  3.3755   ...      9.5702   9.0766   1.6580   3.5813  15.1874
# 4  10.6048  2.9890   ...      4.2259   9.1723   1.2835   3.3778  19.5542
#
#    var_195  var_196  var_197  var_198  var_199
# 0   2.4669   4.3654  10.7200  15.4722  -8.7197
# ...

# %%
# distribution of the same features in parallel in train and test datasets.
features = df.columns.values[2:102]
plot_feature_distribution(df, df_test, 'train', 'test', features)

# %%
features = df.columns.values[102:202]
plot_feature_distribution(df, df_test, 'train', 'test', features)

# %%
# # distribution of the mean values per row in the train and test set.
# plt.figure(figsize=(16,6))
# features = df.columns.values[2:202]
# plt.title("Distribution of mean values per row in the train and test set")
# sns.distplot(df[features].mean(axis=1),color="green", kde=True,bins=120, label='train')
# sns.distplot(df_test[features].mean(axis=1),color="blue", kde=True,bins=120, label='test')
# plt.legend()
# plt.show()

# %%
# distribution of the mean values per columns in the train and test set.
plt.figure(figsize=(16,6))
plt.title("Distribution of mean values per column in the train and test set")
plt.hist(df[features].mean(axis=0),color="magenta",bins=120, label='train')
plt.hist(df_test[features].mean(axis=0),color="darkblue",bins=120, label='test')
plt.legend()
plt.show()

# %%
# # the distribution of standard deviation of values per row for train and test datasets.
# plt.figure(figsize=(16,6))
# plt.title("Distribution of std values per row in the train and test set")
# sns.distplot(df[features].std(axis=1),color="black", kde=True,bins=120, label='train')
# sns.distplot(df_test[features].std(axis=1),color="red", kde=True,bins=120, label='test')
# plt.legend();plt.show()

# %%
# the distribution of the standard deviation of values per columns in the train and test datasets.
plt.figure(figsize=(16,6))
plt.title("Distribution of std values per column in the train and test set")
plt.hist(df[features].std(axis=0),color="blue",bins=120, label='train')
plt.hist(df_test[features].std(axis=0),color="green",bins=120, label='test')
plt.legend(); plt.show()

# %%
# # the distribution of the mean value per row in the train dataset, grouped by value of target.
# t0 = df.loc[df['target'] == 0]
# t1 = df.loc[df['target'] == 1]
# plt.figure(figsize=(16,6))
# plt.title("Distribution of mean values per row in the train set")
# sns.distplot(t0[features].mean(axis=1),color="red", kde=True,bins=120, label='target = 0')
# sns.distplot(t1[features].mean(axis=1),color="blue", kde=True,bins=120, label='target = 1')
# plt.legend(); plt.show()

# %%
# distribution of the mean value per column in the train dataset, grouped by value of target.
plt.figure(figsize=(16,6))
plt.title("Distribution of mean values per column in the train set")
plt.hist(t0[features].mean(axis=0),color="green",bins=120, label='target = 0')
plt.hist(t1[features].mean(axis=0),color="darkblue",bins=120, label='target = 1')
plt.legend(); plt.show()

# %%
# # distribution of min per row in the train and test set.
# plt.figure(figsize=(16,6))
# features = df.columns.values[2:202]
# plt.title("Distribution of min values per row in the train and test set")
# plt.hist(df[features].min(axis=1),color="red",bins=120, label='train')
# plt.hist(df_test[features].min(axis=1),color="orange",bins=120, label='test')
# plt.legend()
# plt.show()

# %%
# distribution of min per column in the train and test set.
plt.figure(figsize=(16,6))
features = df.columns.values[2:202]
plt.title("Distribution of min values per column in the train and test set")
plt.hist(df[features].min(axis=0),color="magenta",bins=120, label='train')
plt.hist(df_test[features].min(axis=0),color="darkblue",bins=120, label='test')
plt.legend()
plt.show()

# %%
# # distribution of max values per rows for train and test set.
# plt.figure(figsize=(16,6))
# features = df.columns.values[2:202]
# plt.title("Distribution of max values per row in the train and test set")
# sns.distplot(df[features].max(axis=1),color="brown", kde=True,bins=120, label='train')
# sns.distplot(df_test[features].max(axis=1),color="yellow", kde=True,bins=120, label='test')
# plt.legend()
# plt.show()

# %%
# the max distribution on columns for train and test set.
plt.figure(figsize=(16,6))
features = df.columns.values[2:202]
plt.title("Distribution of max values per column in the train and test set")
plt.hist(df[features].max(axis=0),color="blue",bins=120, label='train')
plt.hist(df_test[features].max(axis=0),color="red",bins=120, label='test')
plt.legend()
plt.show()

# %%
# # the distributions of min values per row in train set, separated on the values of target (0 and 1).
# t0 = df.loc[df['target'] == 0]
# t1 = df.loc[df['target'] == 1]
# plt.figure(figsize=(16,6))
# plt.title("Distribution of min values per row in the train set")
# sns.distplot(t0[features].min(axis=1),color="orange", kde=True,bins=120, label='target = 0')
# sns.distplot(t1[features].min(axis=1),color="darkblue", kde=True,bins=120, label='target = 1')
# plt.legend(); plt.show()

# %%
# the distribution of min values per columns in train set.
plt.figure(figsize=(16,6))
plt.title("Distribution of min values per column in the train set")
plt.hist(t0[features].min(axis=0),color="red",bins=120, label='target = 0')
plt.hist(t1[features].min(axis=0),color="blue",bins=120, label='target = 1')
plt.legend(); plt.show()

# %%
# # the distribution of max values per row in the train set.
# plt.figure(figsize=(16,6))
# plt.title("Distribution of max values per row in the train set")
# sns.distplot(t0[features].max(axis=1),color="gold", kde=True,bins=120, label='target = 0')
# sns.distplot(t1[features].max(axis=1),color="darkblue", kde=True,bins=120, label='target = 1')
# plt.legend(); plt.show()

# %%
# checking for correlation between features
correlations = df[features].corr().abs().unstack().sort_values(kind="quicksort").reset_index()
correlations = correlations[correlations['level_0'] != correlations['level_1']]

# %%
#highest correlated
correlations.tail(10)
# Out:
#        level_0  level_1         0
# 39790  var_183  var_189  0.009359
# 39791  var_189  var_183  0.009359
# 39792  var_174   var_81  0.009490
# 39793   var_81  var_174  0.009490
# 39794   var_81  var_165  0.009714
# 39795  var_165   var_81  0.009714
# 39796   var_53  var_148  0.009788
# 39797  var_148   var_53  0.009788
# 39798   var_26  var_139  0.009844
# 39799  var_139   var_26  0.009844

# %%
#least correlated
correlations.head(10)
# Out:
#    level_0  level_1             0
# 0   var_75  var_191  2.703975e-08
# 1  var_191   var_75  2.703975e-08
# 2  var_173    var_6  5.942735e-08
# 3    var_6  var_173  5.942735e-08
# 4  var_126  var_109  1.313947e-07
# 5  var_109  var_126  1.313947e-07
# 6  var_144   var_27  1.772502e-07
# 7   var_27  var_144  1.772502e-07
# 8  var_177  var_100  3.116544e-07
# 9  var_100  var_177  3.116544e-07

# %%
# features = df.columns.values[2:202]
# unique_max_train = []
# # unique_max_test = []
# for feature in features:
#     values = df[feature].value_counts()
#     unique_max_train.append([feature, values.max(), values.idxmax()])
# #     values = test_df[feature].value_counts()
# #     unique_max_test.append([feature, values.max(), values.idxmax()])

# %%
# np.transpose((pd.DataFrame(unique_max_train, columns=['Feature', 'Max duplicates', 'Value'])).\
#             sort_values(by = 'Max duplicates', ascending=False).head(15))

# %%
# features = df.columns.values[2:203]

# from scipy.stats import normaltest

# # D’Agostino’s K^2 Test on TRAIN DATA
# non_normal_features = []
# for feature in features:
#     stat, p = normaltest(df[feature])
#     if p <= 0.01:
#         print(feature,"not normal")
#         non_normal_features.append(feature)
